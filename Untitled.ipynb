# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from scipy.stats import sem

# %%
nfl_rb_file = "Data/NFLRBDATA_Mod.csv"

# %%
nfl_rb_data_df = pd.read_csv(nfl_rb_file)
#  preview Dataframe
nfl_rb_data_df.head()
# Out:
#    Rk                Player  From    To  No of Season   Tm   Lg      G     GS  \
# 0   1         Emmitt Smith*  1990  2004            15  TOT  NFL  226.0  219.0
# 1   2        Barry Sanders*  1989  1998            10  DET  NFL  153.0  151.0
# 2   3            Frank Gore  2005  2019            15  TOT  NFL  214.0  199.0
# 3   4        Curtis Martin*  1995  2005            11  TOT  NFL  168.0  166.0
# 4   5  LaDainian Tomlinson*  2001  2011            11  TOT  NFL  170.0  155.0
#
#     Att    Yds   Y/A   TD   Y/G
# 0  4409  18355  4.16  164  81.2
# 1  3062  15269  4.99   99  99.8
# 2  3443  15021  4.36   79  70.2
# 3  3518  14101  4.01   90  83.9
# 4  3174  13684  4.31  145  80.5

# %%
nfl_rb_data_df

# %%
current_rb_df= nfl_rb_data_df[nfl_rb_data_df['To']==2019]
current_rb_df.count()
# Out:
# Rk              136
# Player          136
# From            136
# To              136
# No of Season    136
# Tm              136
# Lg              136
# G               136
# GS              136
# Att             136
# Yds             136
# Y/A             123
# TD              136
# Y/G             136
# hof             136
# dtype: int64

# %%
nfl_rb_data_df.shape
# Out:
# (1412, 14)

# %%
#nfl_rb_data_df.loc[0,'Player'][-1]
# Out:
# '*'

# %%
for row in range(nfl_rb_data_df.shape[0]):
    if nfl_rb_data_df.loc[row,'Player'][-1] == '*':
        nfl_rb_data_df.loc[row,'hof'] = 1
    else:
        nfl_rb_data_df.loc[row,'hof'] = 0
nfl_rb_data_df.head()
# Out:
#    Rk                Player  From    To  No of Season   Tm   Lg      G     GS  \
# 0   1         Emmitt Smith*  1990  2004            15  TOT  NFL  226.0  219.0
# 1   2        Barry Sanders*  1989  1998            10  DET  NFL  153.0  151.0
# 2   3            Frank Gore  2005  2019            15  TOT  NFL  214.0  199.0
# 3   4        Curtis Martin*  1995  2005            11  TOT  NFL  168.0  166.0
# 4   5  LaDainian Tomlinson*  2001  2011            11  TOT  NFL  170.0  155.0
#
#     Att    Yds   Y/A   TD   Y/G  hof
# 0  4409  18355  4.16  164  81.2    1
# 1  3062  15269  4.99   99  99.8    1
# 2  3443  15021  4.36   79  70.2    0
# 3  3518  14101  4.01   90  83.9    1
# 4  3174  13684  4.31  145  80.5    1

# %%
current_rb_highyds_df= current_rb_df[current_rb_df['Yds']>1000]
current_rb_highyds_df.count()
hof_rb_df = nfl_rb_data_df[nfl_rb_data_df['hof']==1]
hof_rb_df
# Out:
#       Rk                Player  From    To  No of Season   Tm   Lg      G  \
# 0      1         Emmitt Smith*  1990  2004            15  TOT  NFL  226.0
# 1      2        Barry Sanders*  1989  1998            10  DET  NFL  153.0
# 3      4        Curtis Martin*  1995  2005            11  TOT  NFL  168.0
# 4      5  LaDainian Tomlinson*  2001  2011            11  TOT  NFL  170.0
# 5      6        Jerome Bettis*  1993  2005            13  TOT  NFL  192.0
# 7      8       Marshall Faulk*  1994  2005            12  TOT  NFL  176.0
# 12    13       Thurman Thomas*  1989  2000            12  TOT  NFL  167.0
# 35    36        Terrell Davis*  1995  2001             7  DEN  NFL   78.0
# 68    69         Marcus Allen*  1989  1997             9  TOT  NFL  125.0
# 136  137       Eric Dickerson*  1989  1993             5  TOT  NFL   56.0
#
#         GS   Att    Yds   Y/A   TD   Y/G  hof
# 0    219.0  4409  18355  4.16  164  81.2    1
# 1    151.0  3062  15269  4.99   99  99.8    1
# ...

# %%
x_axis =current_rb_highyds_df['No of Season']
y_axis= current_rb_highyds_df['Yds']
TD= current_rb_highyds_df['TD']
x1_axis=hof_rb_df['No of Season']
y1_axis=hof_rb_df['Yds']
TD1=hof_rb_df['TD']

# %%
plt.scatter(x_axis, y_axis,marker='o',facecolors= 'red',edgecolors="red", s=TD,alpha=0.75)
plt.scatter(x1_axis, y1_axis,marker='o',facecolors= 'blue',edgecolors="white", s=TD1,alpha=0.75)
plt.xlim(0,16)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.axhline(y=8000)
